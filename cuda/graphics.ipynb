# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Add

# %% [markdown]
# ### Время от размера массива

# %%
size_powers = [16, 18, 20, 22, 24, 26, 27, 28]
add_array_size_delays = [0.01792, 0.018848, 0.03584, 0.098208, 0.375328, 1.45171, 2.89712, 5.79971]

plt.figure(figsize=(20, 9))
plt.title("Время от размера массива", fontsize=30)
plt.xlabel("2^* элементов", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(size_powers, add_array_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [8, 16, 32, 64, 128, 256, 512, 1024]
add_block_size_delays = [26.5364, 14.7592, 7.76314, 5.78755, 5.80381, 5.79526, 5.79613, 5.7889]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, add_block_size_delays)
plt.show()

# %% [markdown]
# ## Mul

# %% [markdown]
# ### Время от размера массива

# %%
size_powers = [16, 18, 20, 22, 24, 26, 27, 28]
mul_array_size_delays = [0.021696, 0.016256, 0.0312, 0.097312, 0.375904, 1.45952, 2.90074, 5.79667]

plt.figure(figsize=(20, 9))
plt.title("Время от размера массива", fontsize=30)
plt.xlabel("2^* элементов", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(size_powers, mul_array_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [8, 16, 32, 64, 128, 256, 512, 1024]
mul_block_size_delays = [27.2812, 15.2429, 7.3431, 5.81101, 5.79734, 5.80653, 5.7976, 5.79136]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, mul_block_size_delays)
plt.show()

# %% [markdown]
# ## Matrix Add

# %% [markdown]
# ### Время от размера матрицы

# %%
sizes = [300, 400, 500, 600, 700, 800, 900, 1000]
matrix_add_matrix_size_delays = [0.026208, 0.034144, 0.042016, 0.045856, 0.058496, 0.069536, 0.081344, 0.093952]

plt.figure(figsize=(20, 9))
plt.title("Время от размера матрицы", fontsize=30)
plt.xlabel("Размер матрицы, *х*", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, matrix_add_matrix_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [2, 4, 8, 16, 32]
matrix_add_block_size_delays = [0.210368, 0.07248, 0.03504, 0.052128, 0.096768]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока, *x*", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, matrix_add_block_size_delays)
plt.show()

# %% [markdown]
# ## Matrix Vector Mul

# %% [markdown]
# ### Время от размера матрицы

# %%
sizes = [300, 400, 500, 600, 700, 800, 900, 1000]
matrix_vector_mul_matrix_size_delays = [0.027904, 0.028608, 0.032768, 0.03824, 0.040768, 0.04208, 0.046208, 0.061536]

plt.figure(figsize=(20, 9))
plt.title("Время от размера матрицы", fontsize=30)
plt.xlabel("Размер матрицы, *х*", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, matrix_vector_mul_matrix_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [2, 4, 8, 16, 32]
matrix_vector_mul_block_size_delays = [0.21312, 0.075712, 0.054368, 0.047776, 0.049408]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока, *x*", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, matrix_vector_mul_block_size_delays)
plt.show()

# %% [markdown]
# ## Scalar Mul Sum + Reduction

# %% [markdown]
# ### Время от размера массива

# %%
size_powers = [13, 14, 15, 16, 17, 18, 19, 20]
scalar_mul_1_array_size_delays = [0.568832, 0.56896, 0.594208, 0.691872, 0.84688, 1.54381, 2.35216, 3.88413]

plt.figure(figsize=(20, 9))
plt.title("Время от размера массива", fontsize=30)
plt.xlabel("2^* элементов", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(size_powers, scalar_mul_1_array_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [8, 16, 32, 64, 128, 256, 512, 1024]
scalar_mul_1_block_size_delays = [3.52272, 3.44384, 3.59104, 3.55158, 3.4703, 3.69638, 3.80554, 3.91635]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, scalar_mul_1_block_size_delays)
plt.show()

# %% [markdown]
# ## Scalar Mul Two Reductions

# %% [markdown]
# ### Время от размера массива

# %%
size_powers = [13, 14, 15, 16, 17, 18, 19, 20]
scalar_mul_2_array_size_delays = [0.483904, 0.533696, 0.522656, 0.62336, 0.810432, 1.47258, 2.60349, 3.96378]

plt.figure(figsize=(20, 9))
plt.title("Время от размера массива", fontsize=30)
plt.xlabel("2^* элементов", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(size_powers, scalar_mul_2_array_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [8, 16, 32, 64, 128, 256, 512, 1024]
scalar_mul_2_block_size_delays = [3.96928, 3.92256, 3.97357, 3.9887, 3.72605, 3.8528, 3.79818, 3.75104]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, scalar_mul_2_block_size_delays)
plt.show()

# %% [markdown]
# ## Cosine Vector

# %% [markdown]
# ### Время от размера массива

# %%
size_powers = [13, 14, 15, 16, 17, 18, 19, 20]
cosine_array_size_delays = [1.48, 1.58723, 1.6439, 2.03885, 2.43786, 4.50758, 8.51568, 11.7409]

plt.figure(figsize=(20, 9))
plt.title("Время от размера массива", fontsize=30)
plt.xlabel("2^* элементов", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(size_powers, cosine_array_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [8, 16, 32, 64, 128, 256, 512, 1024]
cosine_block_size_delays = [12.8668, 12.2816, 11.7748, 11.757, 11.9499, 12.019, 11.7258, 11.9583]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, cosine_block_size_delays)
plt.show()

# %% [markdown]
# ## Matrix Mul

# %% [markdown]
# ### Время от размера матрицы

# %%
sizes = [300, 400, 500, 600, 700, 800, 900, 1000]
matrix_mul_matrix_size_delays = [0.075072, 0.12, 0.196416, 0.328352, 0.499104, 0.709586, 1.05866, 1.40586]

plt.figure(figsize=(20, 9))
plt.title("Время от размера матрицы", fontsize=30)
plt.xlabel("Размер матрицы, *х*", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, matrix_mul_matrix_size_delays)
plt.show()

# %% [markdown]
# ### Время от размера блока

# %%
sizes = [2, 4, 8, 16, 32]
matrix_mul_block_size_delays = [36.6059, 5.8407, 1.84816, 1.43398, 1.41584]

plt.figure(figsize=(20, 9))
plt.title("Время от размера блока", fontsize=30)
plt.xlabel("Размер блока, *x*", fontsize=20)
plt.ylabel("Время, мс", fontsize=20)

plt.plot(sizes, matrix_mul_block_size_delays)
plt.show()
